# %%
import os
from getpass import getpass
import urllib

user = input('User name: ')
password = getpass('Password: ')
password = urllib.parse.quote(password) # your password is converted into url format
repo_name = 'cell-tracker-gnn' #input('Repo name: ')

cmd_string = 'git clone https://{0}:{1}@github.com/{0}/{2}.git'.format(user, password, repo_name)

print(cmd_string)# cmd_string, password = "", "" # removing the password from the variable
# Out:
# git clone https://talbenha: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@github.com/talbenha/cell-tracker-gnn.git

# %%
! git clone https://talbenha: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@github.com/talbenha/cell-tracker-gnn.git
# Out:
# Cloning into 'cell-tracker-gnn'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 161 (delta 56), reused 109 (delta 23), pack-reused 0
# Receiving objects: 100% (161/161), 835.34 KiB | 9.28 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
import os
os.chdir(f'./cell-tracker-gnn')
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/My Drive/CellTracking/nature_method_ctc/Fluo-N2DH-SIM+' # TODO: update this path
os.listdir(file_path)

# %%
! git pull
# Out:
# Already up to date.

# %%
# %%bash
# ls /content/drive/MyDrive/CellTracking/nature_method_ctc
# # cp /content/drive/MyDrive/CellTracking/nature_method_ctc/Inference.ipynb ./
# Out:
# ls: cannot access '/content/drive/MyDrive/CellTracking/nature_method_ctc': No such file or directory

# %%
! git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
! git add Inference.ipynb

# %%
! git config --global user.email "talbenha@gmail.com"
! git config --global user.name "talbenha"
! git commit -m "add Colab Notebook with training of Fluo-N2DH-SIM+"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	Miniconda3-py37_4.8.2-Linux-x86_64.sh
# 	cell-tracker-gnn/
# 	outputs/
# 	src/__pycache__/
# 	src/datamodules/extract_features/__pycache__/
# 	src_metric_learning/Data/__pycache__/
# 	src_metric_learning/__pycache__/
# 	src_metric_learning/modules/__pycache__/
# 	src_metric_learning/modules/resnet_2d/__pycache__/
#
# nothing added to commit but untracked files present

# %%
! git push
# Out:
# Everything up-to-date

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################

# try to run the bare minimum to get a new conda env working
env_name = 'cell-tracking-challenge'
conda_path = ''
try:
    conda_path = ! which conda
finally:
    print('')

if (len(conda_path) == 0):
    print('installing miniconda')
    ! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
    ! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
    ! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
    import sys
    sys.path.append('/usr/local/lib/python3.7/site-packages/')
    ! conda init 
    ! conda install -n root _license -y -q
else:
    print('found miniconda')

conda_envs = ! conda env list
res = [i for i in conda_envs if env_name in i]
if (len(res) == 0):
    print(f'not found {env_name} env', len(res))
    ! conda create --name cell-tracking-challenge --file requirements-conda.txt
    # %%bash
    source activate cell-tracking-challenge
    # install other requirements
    pip install -r requirements.txt
else:
    print(f'found {env_name} env', len(res))
# Out:
# found miniconda
# found cell-tracking-challenge env 1

# %%
# %%bash
# conda env list
# # create conda environment python=3.8 pytorch==1.8.0 torchvision==0.9.0 cudatoolkit=11.1 faiss-gpu pytorch-lightning==1.4.9
# Out:
# # conda environments:
# #
# base                  *  /usr/local
# cell-tracking-challenge     /usr/local/envs/cell-tracking-challenge

# %%
# %%bash
# pwd
# # export PATH=../drive/MyDrive/CellTracking/nature_method_ctc/Fluo-N2DH-SIM+ # TODO: update this path
# # echo "${PATH}"
#
# ls ../drive/MyDrive/CellTracking/nature_method_ctc/
# # cd ../drive
# Out:
# /content/cell-tracker-gnn/cell-tracker-gnn
# ls: cannot access '../drive/MyDrive/CellTracking/nature_method_ctc/': No such file or directory

# %%
# %%bash
# source activate cell-tracking-challenge
# export HYDRA_FULL_ERROR=1
# export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path

# %%
# %%bash
# source activate cell-tracking-challenge
# export HYDRA_FULL_ERROR=1
# export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path
#
# # run feat_extract for metric learning -
# python run_feat_extract.py params.input_images="${FOLDER_PATH}/Fluo-N2DH-SIM+" params.input_masks="${FOLDER_PATH}/Fluo-N2DH-SIM+" params.input_seg="${FOLDER_PATH}/Fluo-N2DH-SIM+" params.output_csv="${FOLDER_PATH}/basic_features" params.sequences=['01','02']  params.seg_dir='_GT/TRA' params.basic=True
# Out:
# [2022-06-04 18:23:01,682][numexpr.utils][INFO] - NumExpr defaulting to 2 threads.
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_000.csv
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_001.csv
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_002.csv
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_003.csv
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_004.csv
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_005.csv
# save file to : /content/drive/MyDrive/CellTracking/nature_method_ctc/basic_features/Fluo-N2DH-SIM+/01/csv/frame_006.csv
# ...

# %%
# %%bash
# source activate cell-tracking-challenge
# export HYDRA_FULL_ERROR=1
# export FOLDER_PATH=/content/drive/MyDrive/CellTracking/nature_method_ctc # TODO: update this path
#
# # run metric learning training -
# python run_train_metric_learning.py dataset.kwargs.data_dir_img="${FOLDER_PATH}/Fluo-N2DH-SIM+" dataset.kwargs.data_dir_mask="${FOLDER_PATH}/Fluo-N2DH-SIM+" dataset.kwargs.dir_csv="${FOLDER_PATH}/basic_features/Fluo-N2DH-SIM+" dataset.kwargs.subdir_mask='GT/TRA'
# # output 'all_params.pth' is generated at end, it is the input_model for the next comand line
# Out:
# Process is terminated.

# %%
# run feat_extract for cell tracking training -
! python run_feat_extract.py params.input_images="./data/CTC/Training/Fluo-N2DH-SIM+" params.input_masks="./data/CTC/Training/Fluo-N2DH-SIM+" params.input_seg="./data/CTC/Training/Fluo-N2DH-SIM+" params.output_csv="./data/ct_features/" params.sequences=['01','02']  params.seg_dir='_GT/TRA' params.basic=False params.input_model=<path_to_all_params_produced_in_metric_learning>

# %%
# cell tracking training run 
! python run.py datamodule.dataset_params.main_path="./data/ct_features/Fluo-N2DH-SIM+" datamodule.dataset_params.exp_name="2D_SIM" datamodule.dataset_params.drop_feat=[]
